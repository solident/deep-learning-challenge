# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
csv_path = '/content/drive/MyDrive/Homework15/Resources/charity_data.csv'



#  Import and read the charity_data.csv. 
application_df = pd.read_csv(csv_path)
application_df.head()
# Out:
# Mounted at /content/drive
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 1000].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 2000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_numeric = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_numeric.drop('IS_SUCCESSFUL', axis=1)
y = application_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10
hidden_nodes_layer4 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="softmax"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3120
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 10)                310
#
#  dense_3 (Dense)             (None, 5)                 55
#
#  dense_4 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 5,921
# Trainable params: 5,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# create directory if it does not exist
if not os.path.exists('/content/drive/MyDrive/Homework15/models/model_3'):
    os.makedirs('/content/drive/MyDrive/Homework15/models/model_3')
# Create a callback that saves the model's weights every five epochs
checkpoint_path = "/content/drive/MyDrive/Homework15/models/model_3/weights.{epoch:02d}.hdf5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_weights_only=True, save_freq='epoch', period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 3ms/step - loss: 0.5944 - accuracy: 0.7151
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5721 - accuracy: 0.7260
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5670 - accuracy: 0.7286
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5645 - accuracy: 0.7278
# Epoch 5/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5625 - accuracy: 0.7286
# Epoch 5: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.05.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5627 - accuracy: 0.7285
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5616 - accuracy: 0.7288
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.7303
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5587 - accuracy: 0.7308
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5577 - accuracy: 0.7300
# Epoch 10/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5573 - accuracy: 0.7314
# Epoch 10: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.10.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5572 - accuracy: 0.7315
# Epoch 11/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5563 - accuracy: 0.7303
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5554 - accuracy: 0.7307
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5551 - accuracy: 0.7316
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5544 - accuracy: 0.7311
# Epoch 15/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5537 - accuracy: 0.7318
# Epoch 15: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.15.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5541 - accuracy: 0.7315
# Epoch 16/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5537 - accuracy: 0.7314
# Epoch 17/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5534 - accuracy: 0.7303
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7320
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5520 - accuracy: 0.7312
# Epoch 20/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5523 - accuracy: 0.7317
# Epoch 20: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.20.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5523 - accuracy: 0.7317
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5522 - accuracy: 0.7313
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5519 - accuracy: 0.7312
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5516 - accuracy: 0.7326
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5516 - accuracy: 0.7324
# Epoch 25/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5513 - accuracy: 0.7321
# Epoch 25: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.25.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5513 - accuracy: 0.7322
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5512 - accuracy: 0.7322
# Epoch 27/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5510 - accuracy: 0.7329
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5509 - accuracy: 0.7314
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5505 - accuracy: 0.7336
# Epoch 30/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5510 - accuracy: 0.7331
# Epoch 30: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.30.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5504 - accuracy: 0.7334
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5505 - accuracy: 0.7327
# Epoch 32/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5498 - accuracy: 0.7322
# Epoch 33/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5499 - accuracy: 0.7329
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5497 - accuracy: 0.7339
# Epoch 35/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5494 - accuracy: 0.7333
# Epoch 35: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.35.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7333
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5496 - accuracy: 0.7337
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5493 - accuracy: 0.7331
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5490 - accuracy: 0.7325
# Epoch 39/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5492 - accuracy: 0.7340
# Epoch 40/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5487 - accuracy: 0.7342
# Epoch 40: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.40.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5488 - accuracy: 0.7342
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5487 - accuracy: 0.7329
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5485 - accuracy: 0.7338
# Epoch 43/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5482 - accuracy: 0.7343
# Epoch 44/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5481 - accuracy: 0.7342
# Epoch 45/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5482 - accuracy: 0.7333
# Epoch 45: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.45.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5481 - accuracy: 0.7333
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7332
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7336
# Epoch 48/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5474 - accuracy: 0.7350
# Epoch 49/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5475 - accuracy: 0.7348
# Epoch 50/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7338
# Epoch 50: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.50.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5472 - accuracy: 0.7341
# Epoch 51/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7347
# Epoch 52/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7347
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7347
# Epoch 54/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5468 - accuracy: 0.7350
# Epoch 55/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5469 - accuracy: 0.7347
# Epoch 55: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.55.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5471 - accuracy: 0.7348
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7362
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5463 - accuracy: 0.7350
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7358
# Epoch 59/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7354
# Epoch 60/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5464 - accuracy: 0.7355
# Epoch 60: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.60.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5463 - accuracy: 0.7355
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7350
# Epoch 62/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7353
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7358
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7353
# Epoch 65/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5456 - accuracy: 0.7355
# Epoch 65: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.65.hdf5
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5456 - accuracy: 0.7355
# Epoch 66/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5455 - accuracy: 0.7354
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5456 - accuracy: 0.7354
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7351
# Epoch 69/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5450 - accuracy: 0.7351
# Epoch 70/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5455 - accuracy: 0.7361
# Epoch 70: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.70.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5454 - accuracy: 0.7363
# Epoch 71/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5451 - accuracy: 0.7365
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7348
# Epoch 73/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5452 - accuracy: 0.7368
# Epoch 74/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5448 - accuracy: 0.7371
# Epoch 75/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5446 - accuracy: 0.7375
# Epoch 75: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.75.hdf5
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5447 - accuracy: 0.7371
# Epoch 76/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5447 - accuracy: 0.7356
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7361
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7367
# Epoch 79/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7365
# Epoch 80/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7366
# Epoch 80: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.80.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5444 - accuracy: 0.7367
# Epoch 81/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5444 - accuracy: 0.7371
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7376
# Epoch 83/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7376
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7354
# Epoch 85/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5439 - accuracy: 0.7372
# Epoch 85: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.85.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7372
# Epoch 86/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5442 - accuracy: 0.7364
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7359
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7363
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7363
# Epoch 90/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5439 - accuracy: 0.7369
# Epoch 90: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.90.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7371
# Epoch 91/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5438 - accuracy: 0.7372
# Epoch 92/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7371
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7364
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7369
# Epoch 95/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.7367
# Epoch 95: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.95.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5435 - accuracy: 0.7366
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5432 - accuracy: 0.7376
# Epoch 97/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5435 - accuracy: 0.7372
# Epoch 98/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5436 - accuracy: 0.7365
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7373
# Epoch 100/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5422 - accuracy: 0.7372
# Epoch 100: saving model to /content/drive/MyDrive/Homework15/models/model_3/weights.100.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5429 - accuracy: 0.7367

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5651 - accuracy: 0.7264 - 964ms/epoch - 4ms/step
# Loss: 0.5651443600654602, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
nn.save('/content/drive/MyDrive/Homework15/models/model_3/AlphabetSoupCharity_Optimization2.h5')
